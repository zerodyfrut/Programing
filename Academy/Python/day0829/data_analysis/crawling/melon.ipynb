# %%
import requests
from bs4 import BeautifulSoup

RANK = 100

header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'} 
# 브라우저로 들어가서 접근해야만 실행이됨 -> 이건 그냥 돌려보니 안되서, 해봐야 아는것..
# 가상의 브라우저 정보
response = requests.get('https://www.melon.com/chart/index.htm', headers = header) ## 주간 차트를 크롤링 할 것임
html = response.text

parse = BeautifulSoup(html, 'html.parser') # html document 화

titles  = parse.find_all("div",{"class": "ellipsis rank01"})
singers = parse.find_all("div",{"class": "ellipsis rank02"})
albums = parse.find_all("div",{"class": "ellipsis rank03"})
 
title = []
singer = []
album = []

for t in titles:
    title.append(t.find('a').text)
 
for s in singers:
    singer.append(s.find('span', {"class": "checkEllipsis"}).text)

for a in albums:
    album.append(a.find('a').text)

for i in range(RANK):
    print('%3d위: %s [ %s ] - %s'%(i+1, title[i], album[i], singer[i]))
# Out:
#   1위: Golden [ KPop Demon Hunters (Soundtrack from the Netflix Film) ] - HUNTR/X, EJAE, AUDREY NUNA, REI AMI, KPop Demon Hunters Cast
#   2위: Soda Pop [ KPop Demon Hunters (Soundtrack from the Netflix Film) ] - KPop Demon Hunters Cast, Danny Chung, Saja Boys, Andrew Choi, Neckwav, Kevin Woo, samUIL Lee
#   3위: 뛰어(JUMP) [ 뛰어(JUMP) ] - BLACKPINK
#   4위: FAMOUS [ FAMOUS ] - ALLDAY PROJECT
#   5위: Drowning [ OO-LI ] - WOODZ
#   6위: 시작의 아이 ❍ [ 시작의 아이 ❍ ハジマリのコ Starting With You : ♡ ] - 박다혜, 마크툽 (MAKTUB)
#   7위: Dirty Work [ Dirty Work ] - aespa
#   8위: 시작의 아이 [ 시작의 아이 ハジマリのコ (Starting With You) ] - 마크툽 (MAKTUB)
#   9위: Your Idol [ KPop Demon Hunters (Soundtrack from the Netflix Film) ] - KPop Demon Hunters Cast, Danny Chung, Saja Boys, Andrew Choi, Neckwav, Kevin Woo, samUIL Lee
#  10위: 너에게 닿기를 [ 너에게 닿기를 ] - 10CM
#  11위: 어제보다 슬픈 오늘 [ 어제보다 슬픈 오늘 ] - 우디 (Woody)
#  12위: WICKED [ FAMOUS ] - ALLDAY PROJECT
#  13위: XOXZ [ IVE SECRET ] - IVE (아이브)
#  14위: 모르시나요(PROD.로코베리) [ 모르시나요 ] - 조째즈
# ...
